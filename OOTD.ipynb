# %% [markdown]
# <a href="https://colab.research.google.com/github/SiwarHaddad/CIS_Challenge_2024/blob/main/OOTD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/sdbds/OOTDiffusion-for-windows
# Out:
# Cloning into 'OOTDiffusion-for-windows'...
# remote: Enumerating objects: 863, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 863 (delta 54), reused 37 (delta 37), pack-reused 781 (from 1)
# Receiving objects: 100% (863/863), 23.13 MiB | 8.01 MiB/s, done.
# Resolving deltas: 100% (175/175), done.

# %%
import os
os.chdir("OOTDiffusion-for-windows")

# %%
# !pip install -r requirements-windows.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 GB 383.2 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 101.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.8/126.8 kB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 9.1 MB/s eta 0:00:00
# ...
# WARNING: typer 0.13.0 does not provide the extra 'all'
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 93.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 32.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 106.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 10.7 MB/s eta 0:00:00
# ...

# %%
# !pip install huggingface_hub==0.25.2
# Out:
# WARNING: Ignoring invalid distribution -uggingface-hub (/usr/local/lib/python3.10/dist-packages)
# ...
# WARNING: Ignoring invalid distribution -uggingface-hub (/usr/local/lib/python3.10/dist-packages)

# %%
# !pip install basicsr
# Out:
# WARNING: Ignoring invalid distribution -uggingface-hub (/usr/local/lib/python3.10/dist-packages)
# ...
#   Using cached basicsr-1.4.2.tar.gz (172 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# ...
#   Using cached lmdb-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# ...
#   Using cached tb_nightly-2.19.0a20241121-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached yapf-0.43.0-py3-none-any.whl.metadata (46 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 18.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 77.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 4.7 MB/s eta 0:00:00
# ...
#   Created wheel for basicsr: filename=basicsr-1.4.2-py3-none-any.whl size=214818 sha256=3bb1dda64b448f6d259fe0148fefaf5ce9170d2b4591edd6241033db0c0e68a6
# ...

# %%
# !git lfs install
# Out:
# Updated git hooks.
# Git LFS initialized.

# %%
# !git clone https://huggingface.co/openai/clip-vit-large-patch14 checkpoints/clip-vit-large-patch14
# Out:
# Cloning into 'checkpoints/clip-vit-large-patch14'...
# remote: Enumerating objects: 45, done.
# remote: Total 45 (delta 0), reused 0 (delta 0), pack-reused 45 (from 1)
# Unpacking objects: 100% (45/45), 1.08 MiB | 1.53 MiB/s, done.
# Filtering content: 100% (4/4), 6.37 GiB | 52.13 MiB/s, done.

# %%
# !git clone https://huggingface.co/levihsu/OOTDiffusion
# Out:
# Cloning into 'OOTDiffusion'...
# remote: Enumerating objects: 105, done.
# remote: Counting objects: 100% (101/101), done.
# remote: Compressing objects: 100% (96/96), done.
# remote: Total 105 (delta 29), reused 0 (delta 0), pack-reused 4 (from 1)
# Receiving objects: 100% (105/105), 2.61 MiB | 2.52 MiB/s, done.
# Resolving deltas: 100% (29/29), done.
# Filtering content: 100% (12/12), 14.77 GiB | 41.47 MiB/s, done.

# %%
os.chdir('run')

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('../images/m2.png')
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = mpimg.imread('../images/t.jpg')
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
# !python run_ootd.py --model_path ../images/m2.png --cloth_path ../images/t.jpg --scale 2.0 --sample 4
# Out:
# 2024-11-30 23:12:11.802534: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-30 23:12:11.823230: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-30 23:12:11.829483: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-30 23:12:13.342231: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.98it/s]
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# ...

# %%
img = mpimg.imread('images_output/out_hd_3.png')
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = mpimg.imread('../images/mul2.png')
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = mpimg.imread('../images/u1.jpg')
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
# !python run_ootd.py --model_path ../images/mul2.png --cloth_path ../images/u1.jpg --model_type dc --category 1 --scale 2.0 --sample 4
# Out:
# 2024-11-30 23:17:46.077108: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-30 23:17:46.097904: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-30 23:17:46.103909: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-30 23:17:47.594634: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.21it/s]
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# ...

# %%
img = mpimg.imread('images_output/out_dc_3.png')
plt.imshow(img)
plt.axis('off')
plt.show()
